# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Manoj\Desktop\data\sales_data_final - Copy.csv')

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head(5)
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail(3)
# Out:
#              order_id  order_date   ship_date       ship_mode  \
# 51287  MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288  MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289  CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name   segment      state        country market   region  \
# 51287  Charlotte Melton  Consumer    Managua      Nicaragua  LATAM  Central
# 51288     Tamara Dahlen  Consumer  Chihuahua         Mexico  LATAM    North
# 51289     Jill Matthias  Consumer   Colorado  United States     US     West
#
#        ...         category sub_category  \
# 51287  ...  Office Supplies       Labels
# 51288  ...  Office Supplies       Labels
# 51289  ...  Office Supplies    Fasteners
#
#                                  product_name sales quantity  discount  \
# 51287  Hon Color Coded Labels, 5000 Label Set    26        3       0.0
# 51288  Hon Legal Exhibit Labels, Alphabetical     7        1       0.0
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
#for detail of single or mulutile coloumns

# %%
df['order_id']
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
type(df['order_id'])
# Out:
# pandas.core.series.Series

# %%
# series type is eqivalent to list type and string type pandas consider as object type

# %%
df.dtypes     #defaulst type
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df['year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 51285    2014
# 51286    2014
# 51287    2014
# 51288    2014
# 51289    2014
# Name: year, Length: 51290, dtype: int64

# %%
type(df['year'])
# Out:
# pandas.core.series.Series

# %%
df[['year']]
# Out:
#        year
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
# ...     ...
# 51285  2014
# 51286  2014
# 51287  2014
# 51288  2014
# 51289  2014
#
# [51290 rows x 1 columns]

# %%
type(df[['year']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['year','profit'] # for multiple coloumn can not execute like this
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.idlerc\anaconda folder\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.idlerc\anaconda folder\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.idlerc\anaconda folder\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('year', 'profit')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['year','profit']]
# Out:
#        year    profit
# 0      2011  106.1400
# 1      2011   36.0360
# 2      2011   29.6400
# 3      2011  -26.0550
# 4      2011   37.7700
# ...     ...       ...
# 51285  2014    4.5188
# 51286  2014    0.4200
# 51287  2014   12.3600
# 51288  2014    0.5600
# 51289  2014   -0.6048
#
# [51290 rows x 2 columns]

# %%
type(df[['year','profit']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df[['year','profit','order_date']]
# Out:
#        year    profit  order_date
# 0      2011  106.1400  01-01-2011
# 1      2011   36.0360  01-01-2011
# 2      2011   29.6400  01-01-2011
# 3      2011  -26.0550  01-01-2011
# 4      2011   37.7700  01-01-2011
# ...     ...       ...         ...
# 51285  2014    4.5188  12/31/2014
# 51286  2014    0.4200  12/31/2014
# 51287  2014   12.3600  12/31/2014
# 51288  2014    0.5600  12/31/2014
# 51289  2014   -0.6048  12/31/2014
#
# [51290 rows x 3 columns]

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.describe()   #give the int and float type value by defualt
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.dtypes=='object'   #give the object type data as true
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df.dtypes[df.dtypes=='float']
# Out:
# discount         float64
# profit           float64
# shipping_cost    float64
# dtype: object

# %%
df[df.dtypes[df.dtypes=='float'].index]
# Out:
#        discount    profit  shipping_cost
# 0           0.0  106.1400          35.46
# 1           0.1   36.0360           9.72
# 2           0.0   29.6400           8.17
# 3           0.5  -26.0550           4.82
# 4           0.1   37.7700           4.70
# ...         ...       ...            ...
# 51285       0.2    4.5188           0.89
# 51286       0.0    0.4200           0.49
# 51287       0.0   12.3600           0.35
# 51288       0.0    0.5600           0.20
# 51289       0.2   -0.6048           0.17
#
# [51290 rows x 3 columns]

# %%
df[df.dtypes[df.dtypes=='float'].index].describe()
# Out:
#            discount        profit  shipping_cost
# count  51290.000000  51290.000000   51290.000000
# mean       0.142908     28.641740      26.375915
# std        0.212280    174.424113      57.296804
# min        0.000000  -6599.978000       0.000000
# 25%        0.000000      0.000000       2.610000
# 50%        0.000000      9.240000       7.790000
# 75%        0.200000     36.810000      24.450000
# max        0.850000   8399.976000     933.570000

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_id']
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df[['order_id']]
# Out:
#               order_id
# 0         AG-2011-2040
# 1        IN-2011-47883
# 2         HU-2011-1220
# 3      IT-2011-3647632
# 4        IN-2011-47883
# ...                ...
# 51285   CA-2014-115427
# 51286     MO-2014-2560
# 51287   MX-2014-110527
# 51288   MX-2014-114783
# 51289   CA-2014-156720
#
# [51290 rows x 1 columns]

# %%
df['order_id'][1:4]  #slicing
# Out:
# 1      IN-2011-47883
# 2       HU-2011-1220
# 3    IT-2011-3647632
# Name: order_id, dtype: object

# %%
df[['order_id']][1:40:2]
# Out:
#            order_id
# 1     IN-2011-47883
# 3   IT-2011-3647632
# 5     IN-2011-47883
# 7     IN-2011-79397
# 9      IZ-2011-4680
# 11    IN-2011-65159
# 13    IN-2011-33652
# 15   MX-2011-160234
# 17    ID-2011-80230
# 19    ID-2011-12596
# 21     IR-2011-7690
# 23     TZ-2011-7370
# 25    IN-2011-65159
# 27   MX-2011-111255
# 29   MX-2011-158771
# 31   MX-2011-111255
# 33   US-2011-136007
# 35   MX-2011-159373
# 37  IT-2011-2942451
# 39    IN-2011-33036

# %%
df[['order_id']][0::]
# Out:
#               order_id
# 0         AG-2011-2040
# 1        IN-2011-47883
# 2         HU-2011-1220
# 3      IT-2011-3647632
# 4        IN-2011-47883
# ...                ...
# 51285   CA-2014-115427
# 51286     MO-2014-2560
# 51287   MX-2014-110527
# 51288   MX-2014-114783
# 51289   CA-2014-156720
#
# [51290 rows x 1 columns]

# %%
df[['order_id']][0::50]
# Out:
#               order_id
# 0         AG-2011-2040
# 50     ES-2011-5496179
# 100      IN-2011-61302
# 150    ES-2011-1460199
# 200    ES-2011-1374122
# ...                ...
# 51050  ES-2014-4107155
# 51100  ES-2014-4107155
# 51150     ML-2014-7360
# 51200     MA-2014-3430
# 51250    IN-2014-78228
#
# [1026 rows x 1 columns]

# %%
df[['order_id']][::-1]
# Out:
#               order_id
# 51289   CA-2014-156720
# 51288   MX-2014-114783
# 51287   MX-2014-110527
# 51286     MO-2014-2560
# 51285   CA-2014-115427
# ...                ...
# 4        IN-2011-47883
# 3      IT-2011-3647632
# 2         HU-2011-1220
# 1        IN-2011-47883
# 0         AG-2011-2040
#
# [51290 rows x 1 columns]

# %%
#for add new coloumn

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['category1'] = "sudh"

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['category2'] = "sudh" "manoj"

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'category2'],
#       dtype='object')

# %%
df['order_id']
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
[df['order_id'].isnull()]     #for null value
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  51285    False
#  51286    False
#  51287    False
#  51288    False
#  51289    False
#  Name: order_id, Length: 51290, dtype: bool]

# %%
df1 = pd.read_excel(r'C:\Users\Manoj\Desktop\data\Dress Sales.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_780/128989573.py in <module>
# ----> 1 df1 = pd.read_excel(r'C:\Users\Manoj\Desktop\data\Dress Sales.xlsx')
#
# ~\.idlerc\anaconda folder\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\.idlerc\anaconda folder\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
# ...

# %%
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df1.columns
# Out:
# Index([         'Dress_ID',         '29/8/2013',         '31/8/2013',
#        2013-02-09 00:00:00, 2013-04-09 00:00:00, 2013-06-09 00:00:00,
#        2013-08-09 00:00:00, 2013-10-09 00:00:00, 2013-12-09 00:00:00,
#                '14/9/2013',         '16/9/2013',         '18/9/2013',
#                '20/9/2013',         '22/9/2013',         '24/9/2013',
#                '26/9/2013',         '28/9/2013',         '30/9/2013',
#        2013-02-10 00:00:00, 2013-04-10 00:00:00, 2013-06-10 00:00:00,
#        2010-08-10 00:00:00, 2013-10-10 00:00:00, 2013-12-10 00:00:00,
#                 'unknown1',           'unkwnon'],
#       dtype='object')

# %%
df1['unkwnon']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 495   NaN
# 496   NaN
# 497   NaN
# 498   NaN
# 499   NaN
# Name: unkwnon, Length: 500, dtype: float64

# %%
df1['unkwnon'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: unkwnon, Length: 500, dtype: bool

# %%
df1.dtypes
# Out:
# Dress_ID                 int64
# 29/8/2013                int64
# 31/8/2013                int64
# 2013-02-09 00:00:00      int64
# 2013-04-09 00:00:00      int64
# 2013-06-09 00:00:00      int64
# 2013-08-09 00:00:00      int64
# 2013-10-09 00:00:00      int64
# 2013-12-09 00:00:00     object
# 14/9/2013               object
# 16/9/2013               object
# 18/9/2013               object
# 20/9/2013               object
# 22/9/2013               object
# 24/9/2013                int64
# 26/9/2013              float64
# 28/9/2013                int64
# 30/9/2013              float64
# 2013-02-10 00:00:00    float64
# 2013-04-10 00:00:00    float64
# 2013-06-10 00:00:00      int64
# 2010-08-10 00:00:00    float64
# 2013-10-10 00:00:00    float64
# 2013-12-10 00:00:00      int64
# unknown1               float64
# unkwnon                float64
# dtype: object

# %%
df1[df1.dtypes[df1.dtypes=='object'].index]
# Out:
#     2013-12-09 00:00:00 14/9/2013 16/9/2013 18/9/2013 20/9/2013 22/9/2013
# 0                  3119      3204      3277      3321      3386      3479
# 1                  1558      1756      1878      1985      2106      2454
# 2                    10        10        10        10        10        11
# 3                  1723      1746      1783      1796      1812      1845
# 4                  1638      1655      1681      1743      1824      1919
# ..                  ...       ...       ...       ...       ...       ...
# 495                 525       519       511       501       492       480
# 496                 850       844       841       845       851       864
# 497                 694       690       686       674       665       658
# 498                 268       270       272       272       264       264
# 499                 578       585       590       599       605       619
#
# [500 rows x 6 columns]

# %%
df1[df1.dtypes[df1.dtypes=='int64'].index]
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'category2'],
#       dtype='object')

# %%
#fetch the max profit person detail

# %%
df[df['profit'] == max]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year, category1, category2]
# Index: []
#
# [0 rows x 23 columns]

# %%
max(df['profit'])
# Out:
# 8399.976

# %%
df[df['profit'] == max(df['profit'])]
# Out:
#              order_id  order_date   ship_date       ship_mode customer_name  \
# 29530  CA-2013-118689  10-03-2013  10-10-2013  Standard Class  Tamara Chand
#
#          segment    state        country market   region  ... sub_category  \
# 29530  Corporate  Indiana  United States     US  Central  ...      Copiers
#
#                                 product_name   sales quantity discount  \
# 29530  Canon imageCLASS 2200 Advanced Copier  17,500        5      0.0
#
#          profit  shipping_cost  order_priority  year category1
# 29530  8399.976         349.07          Medium  2013      sudh
#
# [1 rows x 22 columns]

# %%
#fetch the min profit person detail

# %%
min(df['profit'])
# Out:
# -6599.978

# %%
df[df['profit'] == min(df['profit'])]
# Out:
#              order_id  order_date   ship_date       ship_mode  customer_name  \
# 31884  CA-2013-108196  11/26/2013  12-03-2013  Standard Class  Cindy Stewart
#
#         segment state        country market region  ... sub_category  \
# 31884  Consumer  Ohio  United States     US   East  ...     Machines
#
#                                     product_name  sales quantity discount  \
# 31884  Cubify CubeX 3D Printer Double Head Print  4,500        5      0.7
#
#          profit  shipping_cost  order_priority  year category1
# 31884 -6599.978         451.63             Low  2013      sudh
#
# [1 rows x 22 columns]

# %%
#persone name who got min profit

# %%
df[df['profit'] == min(df['profit'])]['customer_name']
# Out:
# 31884    Cindy Stewart
# Name: customer_name, dtype: object

# %%
df['country']
# Out:
# 0              Algeria
# 1            Australia
# 2              Hungary
# 3               Sweden
# 4            Australia
#              ...
# 51285    United States
# 51286          Morocco
# 51287        Nicaragua
# 51288           Mexico
# 51289    United States
# Name: country, Length: 51290, dtype: object

# %%
len(df['country'])
# Out:
# 51290

# %%
df['country']=='Sweden'
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: country, Length: 51290, dtype: bool

# %%
#all detail country wise

# %%
df[df['country']=='Sweden']
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183  02-03-2011  02-05-2011    Second Class
# 1342   IT-2011-5233011   3/31/2011  04-06-2011  Standard Class
# 1554   IT-2011-2419493  04-12-2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014  01-01-2015     First Class
# 51121  IT-2014-2362249  12/29/2014  01-01-2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# ...

# %%
#lenth

# %%
len(df[df['country']=='Sweden'])
# Out:
# 203

# %%
#want to greater than or less value

# %%
df['shipping_cost']
# Out:
# 0        35.46
# 1         9.72
# 2         8.17
# 3         4.82
# 4         4.70
#          ...
# 51285     0.89
# 51286     0.49
# 51287     0.35
# 51288     0.20
# 51289     0.17
# Name: shipping_cost, Length: 51290, dtype: float64

# %%
df[df['shipping_cost']>80]
# Out:
#              order_id  order_date   ship_date       ship_mode  \
# 7       IN-2011-79397  01-03-2011  01-03-2011        Same Day
# 8       ID-2011-80230  01-03-2011  01-09-2011  Standard Class
# 9        IZ-2011-4680  01-03-2011  01-07-2011  Standard Class
# 27     MX-2011-111255  01-04-2011  01-09-2011    Second Class
# 43     MX-2011-109267  01-05-2011  01-09-2011  Standard Class
# ...               ...         ...         ...             ...
# 51154   IN-2014-49206  12/30/2014  01-01-2015    Second Class
# 51228  MX-2014-116267  12/31/2014  01-03-2015    Second Class
# 51229   IN-2014-43550  12/31/2014  01-01-2015     First Class
# 51230    RS-2014-1460  12/31/2014  01-02-2015    Second Class
# 51231   IN-2014-30390  12/31/2014  01-03-2015     First Class
#
#              customer_name    segment            state      country market  \
# 7              Kean Nguyen  Corporate  New South Wales    Australia   APAC
# ...

# %%
#want greater or less or equal to than value in according to country

# %%
df[df['shipping_cost']>80]['country']
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df[(df['shipping_cost']>100) & (df['profit']<10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230  01-03-2011  01-09-2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672  02-02-2011  02-05-2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014  01-01-2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014  01-02-2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014  01-01-2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
df[(df['profit']>1000) & (df['shipping_cost']>100)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 548      ID-2011-64599  02-10-2011   2/15/2011  Standard Class
# 645    IT-2011-1978668   2/16/2011   2/19/2011    Second Class
# 945     MX-2011-152681  03-08-2011   3/13/2011  Standard Class
# 1015     IN-2011-24832  03-12-2011   3/17/2011  Standard Class
# 1024   ES-2011-4699764   3/14/2011   3/17/2011    Second Class
# ...                ...         ...         ...             ...
# 49305    IN-2014-78900  12-03-2014  12-07-2014  Standard Class
# 49620  IT-2014-4540740  12-07-2014  12-08-2014     First Class
# 50422  ES-2014-4262012  12/19/2014  12/25/2014  Standard Class
# 50602     CA-2014-6550  12/23/2014  12/25/2014    Second Class
# 50777   CA-2014-145219  12/25/2014  12/26/2014     First Class
#
#         customer_name      segment          state        country  market  \
# 548       Carol Adams    Corporate       Shizuoka          Japan    APAC
# ...

# %%
#custome name who got max profit

# %%
df[df['profit'] == max(df['profit'])]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df['profit'].max()
# Out:
# 8399.976

# %%
max(df['profit'])
# Out:
# 8399.976

# %%
df[['profit','customer_name']].max()
# Out:
# profit                     8399.976
# customer_name    Zuschuss Donatelli
# dtype: object

# %%
df[['profit','customer_name','quantity','shipping_cost']].max()
# Out:
# profit                     8399.976
# customer_name    Zuschuss Donatelli
# quantity                         14
# shipping_cost                933.57
# dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'category2'],
#       dtype='object')

# %%
df[['profit','customer_name']]
# Out:
#          profit     customer_name
# 0      106.1400   Toby Braunhardt
# 1       36.0360       Joseph Holt
# 2       29.6400     Annie Thurman
# 3      -26.0550      Eugene Moren
# 4       37.7700       Joseph Holt
# ...         ...               ...
# 51285    4.5188        Erica Bern
# 51286    0.4200         Liz Preis
# 51287   12.3600  Charlotte Melton
# 51288    0.5600     Tamara Dahlen
# 51289   -0.6048     Jill Matthias
#
# [51290 rows x 2 columns]

# %%
df['order_date']
# Out:
# 0        01-01-2011
# 1        01-01-2011
# 2        01-01-2011
# 3        01-01-2011
# 4        01-01-2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
#convert to date time

# %%
date = pd.to_datetime(df['order_date'])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#store this data as new column

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['converted_order_date']
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: converted_order_date, Length: 51290, dtype: datetime64[ns]

# %%
df['converted_order_date'].dt.year
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 51285    2014
# 51286    2014
# 51287    2014
# 51288    2014
# 51289    2014
# Name: converted_order_date, Length: 51290, dtype: int64

# %%
df['converted_order_date'].dt.month
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 51285    12
# 51286    12
# 51287    12
# 51288    12
# 51289    12
# Name: converted_order_date, Length: 51290, dtype: int64

# %%
df['converted_order_date'].dt.week
# Out:
# C:\Users\Manoj\AppData\Local\Temp/ipykernel_14356/3539306284.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['converted_order_date'].dt.week
# 0        52
# 1        52
# 2        52
# 3        52
# 4        52
#          ..
# 51285     1
# 51286     1
# 51287     1
# 51288     1
# 51289     1
# Name: converted_order_date, Length: 51290, dtype: int64

# %%
# creat only year coloumn

# %%
df['only year']= df['converted_order_date'].dt.year

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['only month']= df['converted_order_date'].dt.month

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['only week']= df['converted_order_date'].dt.week
# Out:
# C:\Users\Manoj\AppData\Local\Temp/ipykernel_14356/3944350308.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['only week']= df['converted_order_date'].dt.week

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#extract data year wise

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'category2', 'converted_order_date', 'only year',
#        'only month', 'only week'],
#       dtype='object')

# %%
df[df['only year']==2014]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 33759  ES-2014-2774938  01-01-2014  01-03-2014    Second Class
# 33760    IN-2014-47134  01-01-2014  01-05-2014  Standard Class
# 33761  IT-2014-4810734  01-01-2014  01-03-2014    Second Class
# 33762   US-2014-105830  01-01-2014  01-03-2014     First Class
# 33763   CA-2014-160395  01-01-2014  01-07-2014  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# ...

# %%
y = [2,9,2,5,1,2,9,5,3,8,2,5,6]
pd.value_counts(y)
# Out:
# 2    4
# 5    3
# 9    2
# 1    1
# 3    1
# 8    1
# 6    1
# dtype: int64

# %%
#find the count of entity

# %%
df['only month'].value_counts()   #sorting in descnding order
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: only month, dtype: int64

# %%
df['profit'].value_counts()
# Out:
#  0.0000     668
#  4.3200      70
#  3.9600      69
#  7.9200      67
#  2.6400      63
#            ...
# -1.3995       1
#  37.1400      1
# -2.2650       1
# -18.4230      1
# -0.6048       1
# Name: profit, Length: 24575, dtype: int64

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'category2'],
#       dtype='object')

# %%
#try to find out cost of compayny (shipment cost +discount)

# %%
df['cost_to_company']= df['discount']+df['shipping_cost']

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#try to find out cost of product -->  (profit) - (shipment cost +discount)

# %%
df['cost_of_product']= df['profit'] - df['cost_to_company']

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#for which product id cost of company highest

# %%
df[df['cost_to_company']==max(df['cost_to_company'])]
# Out:
#              order_id order_date  ship_date ship_mode customer_name   segment  \
# 13891  CA-2012-124891  7/31/2012  7/31/2012  Same Day   Rick Hansen  Consumer
#
#           state        country market region  ... order_priority  year  \
# 13891  New York  United States     US   East  ...       Critical  2012
#
#       category1  category2 converted_order_date  only year  only month  \
# 13891      sudh  sudhmanoj           2012-07-31       2012           7
#
#        only week  cost_to_company cost_of_product
# 13891         31           933.57       -171.3855
#
# [1 rows x 29 columns]

# %%
max(df['cost_to_company'])
# Out:
# 933.57

# %%
df[df['cost_to_company']==max(df['cost_to_company'])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
#for delet column but not permanently

# %%
df.drop('cost_to_company',axis=1)
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()   #but originally not deleted
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   order_priority  year category1 converted_order_date order_date_year  \
# ...

# %%
#delet column permanently by two way

# %%
df.drop('only year',axis=1,inplace=True)

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority  year category1 converted_order_date  \
# ...

# %%
#other way to delet by reasign complete data

# %%
df=df.drop('order date_year',axis=1)

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
# ...

# %%
#delet raw but not permanently

# %%
df.drop(1)
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 5        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
# ...

# %%
#delet raw permanetly

# %%
df.drop(1,inplace=True)

# %%
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 5    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
# 5     Consumer  New South Wales  Australia    APAC  Oceania  ...   15.342
#
# ...

# %%
#raw filter wise

# %%
df.loc[[2,3]]
# Out:
#           order_id  order_date   ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220  01-01-2011  01-05-2011  Second Class  Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ...  profit shipping_cost  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...  29.640          8.17
# 3  Home Office  Stockholm   Sweden     EU  North  ... -26.055          4.82
#
#   order_priority  year category1  converted_order_date  order_date_year  \
# 2           High  2011      sudh            2011-01-01             2011
# 3           High  2011      sudh            2011-01-01             2011
#
#    only month  only week cost_to_company
# 2           1         52            8.17
# 3           1         52            5.32
#
# [2 rows x 27 columns]

# %%
df.loc[2:10]
# Out:
#            order_id  order_date   ship_date       ship_mode     customer_name  \
# 2      HU-2011-1220  01-01-2011  01-05-2011    Second Class     Annie Thurman
# 3   IT-2011-3647632  01-01-2011  01-05-2011    Second Class      Eugene Moren
# 4     IN-2011-47883  01-01-2011  01-08-2011  Standard Class       Joseph Holt
# 5     IN-2011-47883  01-01-2011  01-08-2011  Standard Class       Joseph Holt
# 6      CA-2011-1510  01-02-2011  01-06-2011  Standard Class   Magdelene Morse
# 7     IN-2011-79397  01-03-2011  01-03-2011        Same Day       Kean Nguyen
# 8     ID-2011-80230  01-03-2011  01-09-2011  Standard Class      Ken Lonsdale
# 9      IZ-2011-4680  01-03-2011  01-07-2011  Standard Class  Lindsay Williams
# 10    IN-2011-65159  01-03-2011  01-07-2011    Second Class      Larry Blacks
#
#         segment             state      country  market          region  ...  \
# 2      Consumer          Budapest      Hungary    EMEA            EMEA  ...
# ...

# %%
df.loc[2:10:2]
# Out:
#          order_id  order_date   ship_date       ship_mode    customer_name  \
# 2    HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 4   IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 6    CA-2011-1510  01-02-2011  01-06-2011  Standard Class  Magdelene Morse
# 8   ID-2011-80230  01-03-2011  01-09-2011  Standard Class     Ken Lonsdale
# 10  IN-2011-65159  01-03-2011  01-07-2011    Second Class     Larry Blacks
#
#      segment             state      country  market          region  ...  \
# 2   Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 4   Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6   Consumer           Ontario       Canada  Canada          Canada  ...
# 8   Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 10  Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
# ...

# %%
df.loc[::-1]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# ...                ...         ...         ...             ...
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
#
#           customer_name      segment             state        country  market  \
# 51289     Jill Matthias     Consumer          Colorado  United States      US
# ...

# %%
#filter raw and column together

# %%
#loc function filter or slicing the data as per the name of raw and column
#iloc function filter or slicing the data as per the index of raw and column

# %%
df.loc[0:4,['order_id','order_date','ship_date']]   #loc udearstands the name basis or what exctaly the value
# Out:
#           order_id  order_date   ship_date
# 0     AG-2011-2040  01-01-2011  01-06-2011
# 2     HU-2011-1220  01-01-2011  01-05-2011
# 3  IT-2011-3647632  01-01-2011  01-05-2011
# 4    IN-2011-47883  01-01-2011  01-08-2011

# %%
df.iloc[0:4,0:3]    #iloc understand the default one indexm as system read
# Out:
#           order_id  order_date   ship_date
# 0     AG-2011-2040  01-01-2011  01-06-2011
# 2     HU-2011-1220  01-01-2011  01-05-2011
# 3  IT-2011-3647632  01-01-2011  01-05-2011
# 4    IN-2011-47883  01-01-2011  01-08-2011

# %%
df.iloc[1:5,3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
df.iloc[2:5,3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer

# %%
#filter all numeric coloumns

# %%
df.dtypes
# Out:
# order_id                        object
# order_date                      object
# ship_date                       object
# ship_mode                       object
# customer_name                   object
# segment                         object
# state                           object
# country                         object
# market                          object
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales                           object
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# order_priority                  object
# year                             int64
# category1                       object
# category2                       object
# converted_order_date    datetime64[ns]
# ...

# %%
df[df.dtypes[(df.dtypes=='int64')|(df.dtypes=='object')].index]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df2=df[df.dtypes[(df.dtypes=='float64')|(df.dtypes=='int64')].index]

# %%
df2
# Out:
#        quantity  discount    profit  shipping_cost  year  only year  \
# 0             2       0.0  106.1400          35.46  2011       2011
# 1             3       0.1   36.0360           9.72  2011       2011
# 2             4       0.0   29.6400           8.17  2011       2011
# 3             3       0.5  -26.0550           4.82  2011       2011
# 4             5       0.1   37.7700           4.70  2011       2011
# ...         ...       ...       ...            ...   ...        ...
# 51285         2       0.2    4.5188           0.89  2014       2014
# 51286         1       0.0    0.4200           0.49  2014       2014
# 51287         3       0.0   12.3600           0.35  2014       2014
# 51288         1       0.0    0.5600           0.20  2014       2014
# 51289         3       0.2   -0.6048           0.17  2014       2014
#
#        only month  only week  cost_to_company  cost_of_product
# 0               1         52            35.46          70.6800
# ...

# %%
df2[df2>100]
# Out:
#        quantity  discount  profit  shipping_cost  year  only year  only month  \
# 0           NaN       NaN  106.14            NaN  2011       2011         NaN
# 1           NaN       NaN     NaN            NaN  2011       2011         NaN
# 2           NaN       NaN     NaN            NaN  2011       2011         NaN
# 3           NaN       NaN     NaN            NaN  2011       2011         NaN
# 4           NaN       NaN     NaN            NaN  2011       2011         NaN
# ...         ...       ...     ...            ...   ...        ...         ...
# 51285       NaN       NaN     NaN            NaN  2014       2014         NaN
# 51286       NaN       NaN     NaN            NaN  2014       2014         NaN
# 51287       NaN       NaN     NaN            NaN  2014       2014         NaN
# 51288       NaN       NaN     NaN            NaN  2014       2014         NaN
# 51289       NaN       NaN     NaN            NaN  2014       2014         NaN
#
# ...

# %%
df3=df2[df2>20]

# %%
df3
# Out:
#        quantity  discount   profit  shipping_cost  year  only year  \
# 0           NaN       NaN  106.140          35.46  2011       2011
# 1           NaN       NaN   36.036            NaN  2011       2011
# 2           NaN       NaN   29.640            NaN  2011       2011
# 3           NaN       NaN      NaN            NaN  2011       2011
# 4           NaN       NaN   37.770            NaN  2011       2011
# ...         ...       ...      ...            ...   ...        ...
# 51285       NaN       NaN      NaN            NaN  2014       2014
# 51286       NaN       NaN      NaN            NaN  2014       2014
# 51287       NaN       NaN      NaN            NaN  2014       2014
# 51288       NaN       NaN      NaN            NaN  2014       2014
# 51289       NaN       NaN      NaN            NaN  2014       2014
#
#        only month  only week  cost_to_company  cost_of_product
# 0             NaN       52.0            35.46           70.680
# ...

# %%
#drop or delet raw that has null value

# %%
df3.dropna()     #all raw has null value that why drop all raw
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year]
# Index: []

# %%
df3
# Out:
#        quantity  discount   profit  shipping_cost  year
# 0           NaN       NaN  106.140          35.46  2011
# 1           NaN       NaN   36.036            NaN  2011
# 2           NaN       NaN   29.640            NaN  2011
# 3           NaN       NaN      NaN            NaN  2011
# 4           NaN       NaN   37.770            NaN  2011
# ...         ...       ...      ...            ...   ...
# 51285       NaN       NaN      NaN            NaN  2014
# 51286       NaN       NaN      NaN            NaN  2014
# 51287       NaN       NaN      NaN            NaN  2014
# 51288       NaN       NaN      NaN            NaN  2014
# 51289       NaN       NaN      NaN            NaN  2014
#
# [51290 rows x 5 columns]

# %%
#drop or delet coulmn that has null value

# %%
df3.dropna(axis=1)
# Out:
#        year
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
# ...     ...
# 51285  2014
# 51286  2014
# 51287  2014
# 51288  2014
# 51289  2014
#
# [51290 rows x 1 columns]

# %%
df3
# Out:
#        quantity  discount   profit  shipping_cost  year
# 0           NaN       NaN  106.140          35.46  2011
# 1           NaN       NaN   36.036            NaN  2011
# 2           NaN       NaN   29.640            NaN  2011
# 3           NaN       NaN      NaN            NaN  2011
# 4           NaN       NaN   37.770            NaN  2011
# ...         ...       ...      ...            ...   ...
# 51285       NaN       NaN      NaN            NaN  2014
# 51286       NaN       NaN      NaN            NaN  2014
# 51287       NaN       NaN      NaN            NaN  2014
# 51288       NaN       NaN      NaN            NaN  2014
# 51289       NaN       NaN      NaN            NaN  2014
#
# [51290 rows x 5 columns]

# %%
#drop or delet raw that has null value upto 4

# %%
df3.dropna(thresh=4)   #all raw has atleast 4 null value that why drop all
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year]
# Index: []

# %%
df3.dropna(thresh=3)  #drop all raw that has upto 3 null value
# Out:
#        quantity  discount   profit  shipping_cost  year
# 0           NaN       NaN  106.140          35.46  2011
# 7           NaN       NaN  110.412         125.32  2011
# 9           NaN       NaN  253.320          81.26  2011
# 27          NaN       NaN  609.840         109.13  2011
# 43          NaN       NaN  999.360         191.20  2011
# ...         ...       ...      ...            ...   ...
# 51238       NaN       NaN   30.000          43.35  2014
# 51241       NaN       NaN   75.150          34.47  2014
# 51242       NaN       NaN   35.920          25.16  2014
# 51243       NaN       NaN   84.060          23.96  2014
# 51245       NaN       NaN  105.000          21.84  2014
#
# [10126 rows x 5 columns]

# %%
df3.dropna(thresh=3,axis=1)
# Out:
#         profit  shipping_cost  year
# 0      106.140          35.46  2011
# 1       36.036            NaN  2011
# 2       29.640            NaN  2011
# 3          NaN            NaN  2011
# 4       37.770            NaN  2011
# ...        ...            ...   ...
# 51285      NaN            NaN  2014
# 51286      NaN            NaN  2014
# 51287      NaN            NaN  2014
# 51288      NaN            NaN  2014
# 51289      NaN            NaN  2014
#
# [51290 rows x 3 columns]

# %%
df3
# Out:
#        quantity  discount   profit  shipping_cost  year
# 0           NaN       NaN  106.140          35.46  2011
# 1           NaN       NaN   36.036            NaN  2011
# 2           NaN       NaN   29.640            NaN  2011
# 3           NaN       NaN      NaN            NaN  2011
# 4           NaN       NaN   37.770            NaN  2011
# ...         ...       ...      ...            ...   ...
# 51285       NaN       NaN      NaN            NaN  2014
# 51286       NaN       NaN      NaN            NaN  2014
# 51287       NaN       NaN      NaN            NaN  2014
# 51288       NaN       NaN      NaN            NaN  2014
# 51289       NaN       NaN      NaN            NaN  2014
#
# [51290 rows x 5 columns]

# %%
#fill null value

# %%
df3.fillna(value=4)
# Out:
#        quantity  discount   profit  shipping_cost  year  only year  \
# 0           4.0       4.0  106.140          35.46  2011       2011
# 1           4.0       4.0   36.036           4.00  2011       2011
# 2           4.0       4.0   29.640           4.00  2011       2011
# 3           4.0       4.0    4.000           4.00  2011       2011
# 4           4.0       4.0   37.770           4.00  2011       2011
# ...         ...       ...      ...            ...   ...        ...
# 51285       4.0       4.0    4.000           4.00  2014       2014
# 51286       4.0       4.0    4.000           4.00  2014       2014
# 51287       4.0       4.0    4.000           4.00  2014       2014
# 51288       4.0       4.0    4.000           4.00  2014       2014
# 51289       4.0       4.0    4.000           4.00  2014       2014
#
#        only month  only week  cost_to_company  cost_of_product
# 0             4.0       52.0            35.46           70.680
# ...

# %%
df3['shipping_cost'].mean()
# Out:
# 76.55043387455422

# %%
df3.fillna(value=df3['shipping_cost'].mean())
# Out:
#         quantity   discount      profit  shipping_cost  year  only year  \
# 0      76.550434  76.550434  106.140000      35.460000  2011       2011
# 1      76.550434  76.550434   36.036000      76.550434  2011       2011
# 2      76.550434  76.550434   29.640000      76.550434  2011       2011
# 3      76.550434  76.550434   76.550434      76.550434  2011       2011
# 4      76.550434  76.550434   37.770000      76.550434  2011       2011
# ...          ...        ...         ...            ...   ...        ...
# 51285  76.550434  76.550434   76.550434      76.550434  2014       2014
# 51286  76.550434  76.550434   76.550434      76.550434  2014       2014
# 51287  76.550434  76.550434   76.550434      76.550434  2014       2014
# 51288  76.550434  76.550434   76.550434      76.550434  2014       2014
# 51289  76.550434  76.550434   76.550434      76.550434  2014       2014
#
#        only month  only week  cost_to_company  cost_of_product
# ...

# %%
df3.fillna(value=df3['profit'].mean())
# Out:
#          quantity    discount      profit  shipping_cost  year  only year  \
# 0      122.020579  122.020579  106.140000      35.460000  2011       2011
# 1      122.020579  122.020579   36.036000     122.020579  2011       2011
# 2      122.020579  122.020579   29.640000     122.020579  2011       2011
# 3      122.020579  122.020579  122.020579     122.020579  2011       2011
# 4      122.020579  122.020579   37.770000     122.020579  2011       2011
# ...           ...         ...         ...            ...   ...        ...
# 51285  122.020579  122.020579  122.020579     122.020579  2014       2014
# 51286  122.020579  122.020579  122.020579     122.020579  2014       2014
# 51287  122.020579  122.020579  122.020579     122.020579  2014       2014
# 51288  122.020579  122.020579  122.020579     122.020579  2014       2014
# 51289  122.020579  122.020579  122.020579     122.020579  2014       2014
#
#        only month   only week  cost_to_company  cost_of_product
# ...

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040  01-01-2011  01-06-2011  Standard Class
# 1        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# 2         HU-2011-1220  01-01-2011  01-05-2011    Second Class
# 3      IT-2011-3647632  01-01-2011  01-05-2011    Second Class
# 4        IN-2011-47883  01-01-2011  01-08-2011  Standard Class
# ...                ...         ...         ...             ...
# 51285   CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288   MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#yearly average profit

# %%
df.groupby('order_date')['profit'].mean()
# Out:
# order_date
# 01-01-2011     33.145500
# 01-01-2013     56.105125
# 01-01-2014      6.807917
# 01-02-2011      3.120000
# 01-02-2012     -7.276061
#                  ...
# 9/29/2014      49.588536
# 9/30/2011     -50.045269
# 9/30/2012    -318.582667
# 9/30/2013      25.639484
# 9/30/2014      -2.231418
# Name: profit, Length: 1430, dtype: float64

# %%
df.groupby('order_date')['shipping_cost'].mean()
# Out:
# order_date
# 01-01-2011    10.778333
# 01-01-2013    37.210417
# 01-01-2014    16.252917
# 01-02-2011    24.100000
# 01-02-2012    40.433929
#                 ...
# 9/29/2014     22.361711
# 9/30/2011     23.781562
# 9/30/2012     13.926667
# 9/30/2013     31.038387
# 9/30/2014     23.535714
# Name: shipping_cost, Length: 1430, dtype: float64

# %%
df.groupby('order_date')['discount'].mean()
# Out:
# order_date
# 01-01-2011    0.133333
# 01-01-2013    0.062500
# 01-01-2014    0.087500
# 01-02-2011    0.000000
# 01-02-2012    0.182857
#                 ...
# 9/29/2014     0.152132
# 9/30/2011     0.300312
# 9/30/2012     0.600000
# 9/30/2013     0.146000
# 9/30/2014     0.132171
# Name: discount, Length: 1430, dtype: float64

# %%
(df.sales )    #object type
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: object

# %%
df.sales.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14356/2967023491.py in <module>
# ----> 1 df.sales.astype(int)
#
# ~\.idlerc\anaconda folder\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\.idlerc\anaconda folder\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
#because in sales data there is ','(commas) in value that why showing error so first need to replace ','

# %%
df.sales
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: object

# %%
df.sales.str.replace(',',"").astype(int)
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: int32

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df['sales']=df.sales.str.replace(',',"").astype(int)

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales               int32
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.groupby('order_date')['sales'].mean()
# Out:
# order_date
# 01-01-2011    134.666667
# 01-01-2013    390.333333
# 01-01-2014    150.541667
# 01-02-2011    314.000000
# 01-02-2012    357.428571
#                  ...
# 9/29/2014     235.960526
# 9/30/2011     188.562500
# 9/30/2012     223.000000
# 9/30/2013     274.193548
# 9/30/2014     192.171429
# Name: sales, Length: 1430, dtype: float64

# %%
df.groupby('order_date')['quantity'].mean()
# Out:
# order_date
# 01-01-2011    3.166667
# 01-01-2013    3.583333
# 01-01-2014    3.208333
# 01-02-2011    1.000000
# 01-02-2012    4.285714
#                 ...
# 9/29/2014     3.144737
# 9/30/2011     3.718750
# 9/30/2012     7.666667
# 9/30/2013     3.870968
# 9/30/2014     3.228571
# Name: quantity, Length: 1430, dtype: float64

# %%
df.groupby('order_date')['quantity'].sum()
# Out:
# order_date
# 01-01-2011     19
# 01-01-2013     86
# 01-01-2014     77
# 01-02-2011      1
# 01-02-2012    120
#              ...
# 9/29/2014     239
# 9/30/2011     119
# 9/30/2012      23
# 9/30/2013     240
# 9/30/2014     226
# Name: quantity, Length: 1430, dtype: int64

# %%
df.groupby('order_date')['sales'].sum()
# Out:
# order_date
# 01-01-2011                                      408120664511455
# 01-01-2013    1,6491,3587292,1901,36229924615524241785951151...
# 01-01-2014    6778463321571603021072031529954354138138404319...
# 01-02-2011                                                  314
# 01-02-2012    2,8221,2304174131,1886279162744521782452651032...
#                                     ...
# 9/29/2014     2,0882,4151,4688481,0591,2421,2758827353392101...
# 9/30/2011     7959405785332523932511424431441698971252116144...
# 9/30/2012                                                643206
# 9/30/2013     1,3215388041,2901,4982,1428591,421553389184347...
# 9/30/2014     1,14572092427733347630325739649532121734450114...
# Name: sales, Length: 1430, dtype: object
